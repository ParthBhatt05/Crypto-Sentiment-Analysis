# %%
pip install bitfinex-tencars

# %%
import bitfinex
import pandas as pd
import numpy as np
import datetime
import time
import os


# A function that fetches the data
def get_data(start=123456789, stop=987654321, symbol='btcusd', interval='1m', tick_limit=99, step=1000):
    # Create the api instance
    api_v2 = bitfinex.bitfinex_v2.api_v2()

    data = []
    start = start - step
    while start < stop:

        start = start + step
        end = start + step
        res = api_v2.candles(symbol=symbol, interval=interval, limit=tick_limit, start=start, end=end)
        data.extend(res)
        print('Retrieving data from {} to {} for {}'.format(pd.to_datetime(start, unit='ms'),
                                                            pd.to_datetime(end, unit='ms'), symbol))
        time.sleep(1.5)
    return data


# Define query parameters
bin_size = '1m'
limit = 1000
time_step = 1000 * 60 * limit

start_time = datetime.datetime(2019, 1, 1, 0, 0)
start_time = time.mktime(start_time.timetuple()) * 1000

stop_time = datetime.datetime(2020, 1, 1, 0, 0)
stop_time = time.mktime(stop_time.timetuple()) * 1000

api_v1 = bitfinex.bitfinex_v1.api_v1()
currencies = ['doge:usd']

saved_path = '/Users/poojan/Desktop/EDA Data'

if os.path.exists(saved_path) is False:
    os.mkdir(saved_path)

for currency in currencies:
    currency_data = get_data(start=start_time, stop=stop_time, symbol=currency, interval=bin_size, tick_limit=limit, step=time_step)

    # Remove error messages
    ind = [np.ndim(x) != 0 for x in currency_data]
    currency_data = [i for (i, v) in zip(currency_data, ind) if v]

    # Create pandas data frame and clean data
    names = ['time', 'open', 'close', 'high', 'low', 'volume']
    df = pd.DataFrame(currency_data, columns=names)
    df.drop_duplicates(inplace=True)
    df['time'] = pd.to_datetime(df['time'], unit='ms')
    df.set_index('time', inplace=True)
    df.sort_index(inplace=True)

    print('Done downloading data. Saving data to .csv.')
    df.to_csv('{}/{}.csv'.format(saved_path, currency))
    print('Done saving data. Moving to next currency.')

print('Data retrieval done')
# Out:
# No keys, only access to public API functions
# No keys, only access to public API functions
# Retrieving data from 2019-01-01 05:00:00 to 2019-01-01 21:40:00 for doge:usd
# Retrieving data from 2019-01-01 21:40:00 to 2019-01-02 14:20:00 for doge:usd
# Retrieving data from 2019-01-02 14:20:00 to 2019-01-03 07:00:00 for doge:usd
# Retrieving data from 2019-01-03 07:00:00 to 2019-01-03 23:40:00 for doge:usd
# Retrieving data from 2019-01-03 23:40:00 to 2019-01-04 16:20:00 for doge:usd
# Retrieving data from 2019-01-04 16:20:00 to 2019-01-05 09:00:00 for doge:usd
# Retrieving data from 2019-01-05 09:00:00 to 2019-01-06 01:40:00 for doge:usd
# Retrieving data from 2019-01-06 01:40:00 to 2019-01-06 18:20:00 for doge:usd
# Retrieving data from 2019-01-06 18:20:00 to 2019-01-07 11:00:00 for doge:usd
# Retrieving data from 2019-01-07 11:00:00 to 2019-01-08 03:40:00 for doge:usd
# Retrieving data from 2019-01-08 03:40:00 to 2019-01-08 20:20:00 for doge:usd
# Retrieving data from 2019-01-08 20:20:00 to 2019-01-09 13:00:00 for doge:usd
# Retrieving data from 2019-01-09 13:00:00 to 2019-01-10 05:40:00 for doge:usd
# Retrieving data from 2019-01-10 05:40:00 to 2019-01-10 22:20:00 for doge:usd
# Retrieving data from 2019-01-10 22:20:00 to 2019-01-11 15:00:00 for doge:usd
# Retrieving data from 2019-01-11 15:00:00 to 2019-01-12 07:40:00 for doge:usd
# Retrieving data from 2019-01-12 07:40:00 to 2019-01-13 00:20:00 for doge:usd
# Retrieving data from 2019-01-13 00:20:00 to 2019-01-13 17:00:00 for doge:usd
# Retrieving data from 2019-01-13 17:00:00 to 2019-01-14 09:40:00 for doge:usd
# Retrieving data from 2019-01-14 09:40:00 to 2019-01-15 02:20:00 for doge:usd
# Retrieving data from 2019-01-15 02:20:00 to 2019-01-15 19:00:00 for doge:usd
# Retrieving data from 2019-01-15 19:00:00 to 2019-01-16 11:40:00 for doge:usd
# Retrieving data from 2019-01-16 11:40:00 to 2019-01-17 04:20:00 for doge:usd
# Retrieving data from 2019-01-17 04:20:00 to 2019-01-17 21:00:00 for doge:usd
# Retrieving data from 2019-01-17 21:00:00 to 2019-01-18 13:40:00 for doge:usd
# Retrieving data from 2019-01-18 13:40:00 to 2019-01-19 06:20:00 for doge:usd
# Retrieving data from 2019-01-19 06:20:00 to 2019-01-19 23:00:00 for doge:usd
# Retrieving data from 2019-01-19 23:00:00 to 2019-01-20 15:40:00 for doge:usd
# Retrieving data from 2019-01-20 15:40:00 to 2019-01-21 08:20:00 for doge:usd
# Retrieving data from 2019-01-21 08:20:00 to 2019-01-22 01:00:00 for doge:usd
# Retrieving data from 2019-01-22 01:00:00 to 2019-01-22 17:40:00 for doge:usd
# Retrieving data from 2019-01-22 17:40:00 to 2019-01-23 10:20:00 for doge:usd
# Retrieving data from 2019-01-23 10:20:00 to 2019-01-24 03:00:00 for doge:usd
# Retrieving data from 2019-01-24 03:00:00 to 2019-01-24 19:40:00 for doge:usd
# Retrieving data from 2019-01-24 19:40:00 to 2019-01-25 12:20:00 for doge:usd
# Retrieving data from 2019-01-25 12:20:00 to 2019-01-26 05:00:00 for doge:usd
# Retrieving data from 2019-01-26 05:00:00 to 2019-01-26 21:40:00 for doge:usd
# Retrieving data from 2019-01-26 21:40:00 to 2019-01-27 14:20:00 for doge:usd
# Retrieving data from 2019-01-27 14:20:00 to 2019-01-28 07:00:00 for doge:usd
# Retrieving data from 2019-01-28 07:00:00 to 2019-01-28 23:40:00 for doge:usd
# Retrieving data from 2019-01-28 23:40:00 to 2019-01-29 16:20:00 for doge:usd
# Retrieving data from 2019-01-29 16:20:00 to 2019-01-30 09:00:00 for doge:usd
# Retrieving data from 2019-01-30 09:00:00 to 2019-01-31 01:40:00 for doge:usd
# Retrieving data from 2019-01-31 01:40:00 to 2019-01-31 18:20:00 for doge:usd
# Retrieving data from 2019-01-31 18:20:00 to 2019-02-01 11:00:00 for doge:usd
# Retrieving data from 2019-02-01 11:00:00 to 2019-02-02 03:40:00 for doge:usd
# Retrieving data from 2019-02-02 03:40:00 to 2019-02-02 20:20:00 for doge:usd
# Retrieving data from 2019-02-02 20:20:00 to 2019-02-03 13:00:00 for doge:usd
# Retrieving data from 2019-02-03 13:00:00 to 2019-02-04 05:40:00 for doge:usd
# Retrieving data from 2019-02-04 05:40:00 to 2019-02-04 22:20:00 for doge:usd
# Retrieving data from 2019-02-04 22:20:00 to 2019-02-05 15:00:00 for doge:usd
# Retrieving data from 2019-02-05 15:00:00 to 2019-02-06 07:40:00 for doge:usd
# Retrieving data from 2019-02-06 07:40:00 to 2019-02-07 00:20:00 for doge:usd
# Retrieving data from 2019-02-07 00:20:00 to 2019-02-07 17:00:00 for doge:usd
# Retrieving data from 2019-02-07 17:00:00 to 2019-02-08 09:40:00 for doge:usd
# Retrieving data from 2019-02-08 09:40:00 to 2019-02-09 02:20:00 for doge:usd
# Retrieving data from 2019-02-09 02:20:00 to 2019-02-09 19:00:00 for doge:usd
# Retrieving data from 2019-02-09 19:00:00 to 2019-02-10 11:40:00 for doge:usd
# Retrieving data from 2019-02-10 11:40:00 to 2019-02-11 04:20:00 for doge:usd
# Retrieving data from 2019-02-11 04:20:00 to 2019-02-11 21:00:00 for doge:usd
# Retrieving data from 2019-02-11 21:00:00 to 2019-02-12 13:40:00 for doge:usd
# Retrieving data from 2019-02-12 13:40:00 to 2019-02-13 06:20:00 for doge:usd
# Retrieving data from 2019-02-13 06:20:00 to 2019-02-13 23:00:00 for doge:usd
# Retrieving data from 2019-02-13 23:00:00 to 2019-02-14 15:40:00 for doge:usd
# Retrieving data from 2019-02-14 15:40:00 to 2019-02-15 08:20:00 for doge:usd
# Retrieving data from 2019-02-15 08:20:00 to 2019-02-16 01:00:00 for doge:usd
# Retrieving data from 2019-02-16 01:00:00 to 2019-02-16 17:40:00 for doge:usd
# Retrieving data from 2019-02-16 17:40:00 to 2019-02-17 10:20:00 for doge:usd
# Retrieving data from 2019-02-17 10:20:00 to 2019-02-18 03:00:00 for doge:usd
# Retrieving data from 2019-02-18 03:00:00 to 2019-02-18 19:40:00 for doge:usd
# Retrieving data from 2019-02-18 19:40:00 to 2019-02-19 12:20:00 for doge:usd
# Retrieving data from 2019-02-19 12:20:00 to 2019-02-20 05:00:00 for doge:usd
# Retrieving data from 2019-02-20 05:00:00 to 2019-02-20 21:40:00 for doge:usd
# Retrieving data from 2019-02-20 21:40:00 to 2019-02-21 14:20:00 for doge:usd
# Retrieving data from 2019-02-21 14:20:00 to 2019-02-22 07:00:00 for doge:usd
# Retrieving data from 2019-02-22 07:00:00 to 2019-02-22 23:40:00 for doge:usd
# Retrieving data from 2019-02-22 23:40:00 to 2019-02-23 16:20:00 for doge:usd
# Retrieving data from 2019-02-23 16:20:00 to 2019-02-24 09:00:00 for doge:usd
# Retrieving data from 2019-02-24 09:00:00 to 2019-02-25 01:40:00 for doge:usd
# Retrieving data from 2019-02-25 01:40:00 to 2019-02-25 18:20:00 for doge:usd
# Retrieving data from 2019-02-25 18:20:00 to 2019-02-26 11:00:00 for doge:usd
# Retrieving data from 2019-02-26 11:00:00 to 2019-02-27 03:40:00 for doge:usd
# Retrieving data from 2019-02-27 03:40:00 to 2019-02-27 20:20:00 for doge:usd
# Retrieving data from 2019-02-27 20:20:00 to 2019-02-28 13:00:00 for doge:usd
# Retrieving data from 2019-02-28 13:00:00 to 2019-03-01 05:40:00 for doge:usd
# Retrieving data from 2019-03-01 05:40:00 to 2019-03-01 22:20:00 for doge:usd
# Retrieving data from 2019-03-01 22:20:00 to 2019-03-02 15:00:00 for doge:usd
# Retrieving data from 2019-03-02 15:00:00 to 2019-03-03 07:40:00 for doge:usd
# Retrieving data from 2019-03-03 07:40:00 to 2019-03-04 00:20:00 for doge:usd
# Retrieving data from 2019-03-04 00:20:00 to 2019-03-04 17:00:00 for doge:usd
# Retrieving data from 2019-03-04 17:00:00 to 2019-03-05 09:40:00 for doge:usd
# Retrieving data from 2019-03-05 09:40:00 to 2019-03-06 02:20:00 for doge:usd
# Retrieving data from 2019-03-06 02:20:00 to 2019-03-06 19:00:00 for doge:usd
# Retrieving data from 2019-03-06 19:00:00 to 2019-03-07 11:40:00 for doge:usd
# Retrieving data from 2019-03-07 11:40:00 to 2019-03-08 04:20:00 for doge:usd
# Retrieving data from 2019-03-08 04:20:00 to 2019-03-08 21:00:00 for doge:usd
# Retrieving data from 2019-03-08 21:00:00 to 2019-03-09 13:40:00 for doge:usd
# Retrieving data from 2019-03-09 13:40:00 to 2019-03-10 06:20:00 for doge:usd
# Retrieving data from 2019-03-10 06:20:00 to 2019-03-10 23:00:00 for doge:usd
# Retrieving data from 2019-03-10 23:00:00 to 2019-03-11 15:40:00 for doge:usd
# Retrieving data from 2019-03-11 15:40:00 to 2019-03-12 08:20:00 for doge:usd
# Retrieving data from 2019-03-12 08:20:00 to 2019-03-13 01:00:00 for doge:usd
# Retrieving data from 2019-03-13 01:00:00 to 2019-03-13 17:40:00 for doge:usd
# Retrieving data from 2019-03-13 17:40:00 to 2019-03-14 10:20:00 for doge:usd
# Retrieving data from 2019-03-14 10:20:00 to 2019-03-15 03:00:00 for doge:usd
# Retrieving data from 2019-03-15 03:00:00 to 2019-03-15 19:40:00 for doge:usd
# Retrieving data from 2019-03-15 19:40:00 to 2019-03-16 12:20:00 for doge:usd
# Retrieving data from 2019-03-16 12:20:00 to 2019-03-17 05:00:00 for doge:usd
# Retrieving data from 2019-03-17 05:00:00 to 2019-03-17 21:40:00 for doge:usd
# Retrieving data from 2019-03-17 21:40:00 to 2019-03-18 14:20:00 for doge:usd
# Retrieving data from 2019-03-18 14:20:00 to 2019-03-19 07:00:00 for doge:usd
# Retrieving data from 2019-03-19 07:00:00 to 2019-03-19 23:40:00 for doge:usd
# Retrieving data from 2019-03-19 23:40:00 to 2019-03-20 16:20:00 for doge:usd
# Retrieving data from 2019-03-20 16:20:00 to 2019-03-21 09:00:00 for doge:usd
# Retrieving data from 2019-03-21 09:00:00 to 2019-03-22 01:40:00 for doge:usd
# Retrieving data from 2019-03-22 01:40:00 to 2019-03-22 18:20:00 for doge:usd
# Retrieving data from 2019-03-22 18:20:00 to 2019-03-23 11:00:00 for doge:usd
# Retrieving data from 2019-03-23 11:00:00 to 2019-03-24 03:40:00 for doge:usd
# Retrieving data from 2019-03-24 03:40:00 to 2019-03-24 20:20:00 for doge:usd
# Retrieving data from 2019-03-24 20:20:00 to 2019-03-25 13:00:00 for doge:usd
# Retrieving data from 2019-03-25 13:00:00 to 2019-03-26 05:40:00 for doge:usd
# Retrieving data from 2019-03-26 05:40:00 to 2019-03-26 22:20:00 for doge:usd
# Retrieving data from 2019-03-26 22:20:00 to 2019-03-27 15:00:00 for doge:usd
# Retrieving data from 2019-03-27 15:00:00 to 2019-03-28 07:40:00 for doge:usd
# Retrieving data from 2019-03-28 07:40:00 to 2019-03-29 00:20:00 for doge:usd
# Retrieving data from 2019-03-29 00:20:00 to 2019-03-29 17:00:00 for doge:usd
# Retrieving data from 2019-03-29 17:00:00 to 2019-03-30 09:40:00 for doge:usd
# Retrieving data from 2019-03-30 09:40:00 to 2019-03-31 02:20:00 for doge:usd
# Retrieving data from 2019-03-31 02:20:00 to 2019-03-31 19:00:00 for doge:usd
# Retrieving data from 2019-03-31 19:00:00 to 2019-04-01 11:40:00 for doge:usd
# Retrieving data from 2019-04-01 11:40:00 to 2019-04-02 04:20:00 for doge:usd
# Retrieving data from 2019-04-02 04:20:00 to 2019-04-02 21:00:00 for doge:usd
# Retrieving data from 2019-04-02 21:00:00 to 2019-04-03 13:40:00 for doge:usd
# Retrieving data from 2019-04-03 13:40:00 to 2019-04-04 06:20:00 for doge:usd
# Retrieving data from 2019-04-04 06:20:00 to 2019-04-04 23:00:00 for doge:usd
# Retrieving data from 2019-04-04 23:00:00 to 2019-04-05 15:40:00 for doge:usd
# Retrieving data from 2019-04-05 15:40:00 to 2019-04-06 08:20:00 for doge:usd
# Retrieving data from 2019-04-06 08:20:00 to 2019-04-07 01:00:00 for doge:usd
# Retrieving data from 2019-04-07 01:00:00 to 2019-04-07 17:40:00 for doge:usd
# Retrieving data from 2019-04-07 17:40:00 to 2019-04-08 10:20:00 for doge:usd
# Retrieving data from 2019-04-08 10:20:00 to 2019-04-09 03:00:00 for doge:usd
# Retrieving data from 2019-04-09 03:00:00 to 2019-04-09 19:40:00 for doge:usd
# Retrieving data from 2019-04-09 19:40:00 to 2019-04-10 12:20:00 for doge:usd
# Retrieving data from 2019-04-10 12:20:00 to 2019-04-11 05:00:00 for doge:usd
# Retrieving data from 2019-04-11 05:00:00 to 2019-04-11 21:40:00 for doge:usd
# Retrieving data from 2019-04-11 21:40:00 to 2019-04-12 14:20:00 for doge:usd
# Retrieving data from 2019-04-12 14:20:00 to 2019-04-13 07:00:00 for doge:usd
# Retrieving data from 2019-04-13 07:00:00 to 2019-04-13 23:40:00 for doge:usd
# Retrieving data from 2019-04-13 23:40:00 to 2019-04-14 16:20:00 for doge:usd
# Retrieving data from 2019-04-14 16:20:00 to 2019-04-15 09:00:00 for doge:usd
# Retrieving data from 2019-04-15 09:00:00 to 2019-04-16 01:40:00 for doge:usd
# Retrieving data from 2019-04-16 01:40:00 to 2019-04-16 18:20:00 for doge:usd
# Retrieving data from 2019-04-16 18:20:00 to 2019-04-17 11:00:00 for doge:usd
# Retrieving data from 2019-04-17 11:00:00 to 2019-04-18 03:40:00 for doge:usd
# Retrieving data from 2019-04-18 03:40:00 to 2019-04-18 20:20:00 for doge:usd
# Retrieving data from 2019-04-18 20:20:00 to 2019-04-19 13:00:00 for doge:usd
# Retrieving data from 2019-04-19 13:00:00 to 2019-04-20 05:40:00 for doge:usd
# Retrieving data from 2019-04-20 05:40:00 to 2019-04-20 22:20:00 for doge:usd
# Retrieving data from 2019-04-20 22:20:00 to 2019-04-21 15:00:00 for doge:usd
# Retrieving data from 2019-04-21 15:00:00 to 2019-04-22 07:40:00 for doge:usd
# Retrieving data from 2019-04-22 07:40:00 to 2019-04-23 00:20:00 for doge:usd
# Retrieving data from 2019-04-23 00:20:00 to 2019-04-23 17:00:00 for doge:usd
# Retrieving data from 2019-04-23 17:00:00 to 2019-04-24 09:40:00 for doge:usd
# Retrieving data from 2019-04-24 09:40:00 to 2019-04-25 02:20:00 for doge:usd
# Retrieving data from 2019-04-25 02:20:00 to 2019-04-25 19:00:00 for doge:usd
# Retrieving data from 2019-04-25 19:00:00 to 2019-04-26 11:40:00 for doge:usd
# Retrieving data from 2019-04-26 11:40:00 to 2019-04-27 04:20:00 for doge:usd
# Retrieving data from 2019-04-27 04:20:00 to 2019-04-27 21:00:00 for doge:usd
# Retrieving data from 2019-04-27 21:00:00 to 2019-04-28 13:40:00 for doge:usd
# Retrieving data from 2019-04-28 13:40:00 to 2019-04-29 06:20:00 for doge:usd
# Retrieving data from 2019-04-29 06:20:00 to 2019-04-29 23:00:00 for doge:usd
# Retrieving data from 2019-04-29 23:00:00 to 2019-04-30 15:40:00 for doge:usd
# Retrieving data from 2019-04-30 15:40:00 to 2019-05-01 08:20:00 for doge:usd
# Retrieving data from 2019-05-01 08:20:00 to 2019-05-02 01:00:00 for doge:usd
# Retrieving data from 2019-05-02 01:00:00 to 2019-05-02 17:40:00 for doge:usd
# Retrieving data from 2019-05-02 17:40:00 to 2019-05-03 10:20:00 for doge:usd
# Retrieving data from 2019-05-03 10:20:00 to 2019-05-04 03:00:00 for doge:usd
# Retrieving data from 2019-05-04 03:00:00 to 2019-05-04 19:40:00 for doge:usd
# Retrieving data from 2019-05-04 19:40:00 to 2019-05-05 12:20:00 for doge:usd
# Retrieving data from 2019-05-05 12:20:00 to 2019-05-06 05:00:00 for doge:usd
# Retrieving data from 2019-05-06 05:00:00 to 2019-05-06 21:40:00 for doge:usd
# Retrieving data from 2019-05-06 21:40:00 to 2019-05-07 14:20:00 for doge:usd
# Retrieving data from 2019-05-07 14:20:00 to 2019-05-08 07:00:00 for doge:usd
# Retrieving data from 2019-05-08 07:00:00 to 2019-05-08 23:40:00 for doge:usd
# Retrieving data from 2019-05-08 23:40:00 to 2019-05-09 16:20:00 for doge:usd
# Retrieving data from 2019-05-09 16:20:00 to 2019-05-10 09:00:00 for doge:usd
# Retrieving data from 2019-05-10 09:00:00 to 2019-05-11 01:40:00 for doge:usd
# Retrieving data from 2019-05-11 01:40:00 to 2019-05-11 18:20:00 for doge:usd
# Retrieving data from 2019-05-11 18:20:00 to 2019-05-12 11:00:00 for doge:usd
# Retrieving data from 2019-05-12 11:00:00 to 2019-05-13 03:40:00 for doge:usd
# Retrieving data from 2019-05-13 03:40:00 to 2019-05-13 20:20:00 for doge:usd
# Retrieving data from 2019-05-13 20:20:00 to 2019-05-14 13:00:00 for doge:usd
# Retrieving data from 2019-05-14 13:00:00 to 2019-05-15 05:40:00 for doge:usd
# Retrieving data from 2019-05-15 05:40:00 to 2019-05-15 22:20:00 for doge:usd
# Retrieving data from 2019-05-15 22:20:00 to 2019-05-16 15:00:00 for doge:usd
# Retrieving data from 2019-05-16 15:00:00 to 2019-05-17 07:40:00 for doge:usd
# Retrieving data from 2019-05-17 07:40:00 to 2019-05-18 00:20:00 for doge:usd
# Retrieving data from 2019-05-18 00:20:00 to 2019-05-18 17:00:00 for doge:usd
# Retrieving data from 2019-05-18 17:00:00 to 2019-05-19 09:40:00 for doge:usd
# Retrieving data from 2019-05-19 09:40:00 to 2019-05-20 02:20:00 for doge:usd
# Retrieving data from 2019-05-20 02:20:00 to 2019-05-20 19:00:00 for doge:usd
# Retrieving data from 2019-05-20 19:00:00 to 2019-05-21 11:40:00 for doge:usd
# Retrieving data from 2019-05-21 11:40:00 to 2019-05-22 04:20:00 for doge:usd
# Retrieving data from 2019-05-22 04:20:00 to 2019-05-22 21:00:00 for doge:usd
# Retrieving data from 2019-05-22 21:00:00 to 2019-05-23 13:40:00 for doge:usd
# Retrieving data from 2019-05-23 13:40:00 to 2019-05-24 06:20:00 for doge:usd
# Retrieving data from 2019-05-24 06:20:00 to 2019-05-24 23:00:00 for doge:usd
# Retrieving data from 2019-05-24 23:00:00 to 2019-05-25 15:40:00 for doge:usd
# Retrieving data from 2019-05-25 15:40:00 to 2019-05-26 08:20:00 for doge:usd
# Retrieving data from 2019-05-26 08:20:00 to 2019-05-27 01:00:00 for doge:usd
# Retrieving data from 2019-05-27 01:00:00 to 2019-05-27 17:40:00 for doge:usd
# Retrieving data from 2019-05-27 17:40:00 to 2019-05-28 10:20:00 for doge:usd
# Retrieving data from 2019-05-28 10:20:00 to 2019-05-29 03:00:00 for doge:usd
# Retrieving data from 2019-05-29 03:00:00 to 2019-05-29 19:40:00 for doge:usd
# Retrieving data from 2019-05-29 19:40:00 to 2019-05-30 12:20:00 for doge:usd
# Retrieving data from 2019-05-30 12:20:00 to 2019-05-31 05:00:00 for doge:usd
# Retrieving data from 2019-05-31 05:00:00 to 2019-05-31 21:40:00 for doge:usd
# Retrieving data from 2019-05-31 21:40:00 to 2019-06-01 14:20:00 for doge:usd
# Retrieving data from 2019-06-01 14:20:00 to 2019-06-02 07:00:00 for doge:usd
# Retrieving data from 2019-06-02 07:00:00 to 2019-06-02 23:40:00 for doge:usd
# Retrieving data from 2019-06-02 23:40:00 to 2019-06-03 16:20:00 for doge:usd
# Retrieving data from 2019-06-03 16:20:00 to 2019-06-04 09:00:00 for doge:usd
# Retrieving data from 2019-06-04 09:00:00 to 2019-06-05 01:40:00 for doge:usd
# Retrieving data from 2019-06-05 01:40:00 to 2019-06-05 18:20:00 for doge:usd
# Retrieving data from 2019-06-05 18:20:00 to 2019-06-06 11:00:00 for doge:usd
# Retrieving data from 2019-06-06 11:00:00 to 2019-06-07 03:40:00 for doge:usd
# Retrieving data from 2019-06-07 03:40:00 to 2019-06-07 20:20:00 for doge:usd
# Retrieving data from 2019-06-07 20:20:00 to 2019-06-08 13:00:00 for doge:usd
# Retrieving data from 2019-06-08 13:00:00 to 2019-06-09 05:40:00 for doge:usd
# Retrieving data from 2019-06-09 05:40:00 to 2019-06-09 22:20:00 for doge:usd
# Retrieving data from 2019-06-09 22:20:00 to 2019-06-10 15:00:00 for doge:usd
# Retrieving data from 2019-06-10 15:00:00 to 2019-06-11 07:40:00 for doge:usd
# Retrieving data from 2019-06-11 07:40:00 to 2019-06-12 00:20:00 for doge:usd
# Retrieving data from 2019-06-12 00:20:00 to 2019-06-12 17:00:00 for doge:usd
# Retrieving data from 2019-06-12 17:00:00 to 2019-06-13 09:40:00 for doge:usd
# Retrieving data from 2019-06-13 09:40:00 to 2019-06-14 02:20:00 for doge:usd
# Retrieving data from 2019-06-14 02:20:00 to 2019-06-14 19:00:00 for doge:usd
# Retrieving data from 2019-06-14 19:00:00 to 2019-06-15 11:40:00 for doge:usd
# Retrieving data from 2019-06-15 11:40:00 to 2019-06-16 04:20:00 for doge:usd
# Retrieving data from 2019-06-16 04:20:00 to 2019-06-16 21:00:00 for doge:usd
# Retrieving data from 2019-06-16 21:00:00 to 2019-06-17 13:40:00 for doge:usd
# Retrieving data from 2019-06-17 13:40:00 to 2019-06-18 06:20:00 for doge:usd
# Retrieving data from 2019-06-18 06:20:00 to 2019-06-18 23:00:00 for doge:usd
# Retrieving data from 2019-06-18 23:00:00 to 2019-06-19 15:40:00 for doge:usd
# Retrieving data from 2019-06-19 15:40:00 to 2019-06-20 08:20:00 for doge:usd
# Retrieving data from 2019-06-20 08:20:00 to 2019-06-21 01:00:00 for doge:usd
# Retrieving data from 2019-06-21 01:00:00 to 2019-06-21 17:40:00 for doge:usd
# Retrieving data from 2019-06-21 17:40:00 to 2019-06-22 10:20:00 for doge:usd
# Retrieving data from 2019-06-22 10:20:00 to 2019-06-23 03:00:00 for doge:usd
# Retrieving data from 2019-06-23 03:00:00 to 2019-06-23 19:40:00 for doge:usd
# Retrieving data from 2019-06-23 19:40:00 to 2019-06-24 12:20:00 for doge:usd
# Retrieving data from 2019-06-24 12:20:00 to 2019-06-25 05:00:00 for doge:usd
# Retrieving data from 2019-06-25 05:00:00 to 2019-06-25 21:40:00 for doge:usd
# Retrieving data from 2019-06-25 21:40:00 to 2019-06-26 14:20:00 for doge:usd
# Retrieving data from 2019-06-26 14:20:00 to 2019-06-27 07:00:00 for doge:usd
# Retrieving data from 2019-06-27 07:00:00 to 2019-06-27 23:40:00 for doge:usd
# Retrieving data from 2019-06-27 23:40:00 to 2019-06-28 16:20:00 for doge:usd
# Retrieving data from 2019-06-28 16:20:00 to 2019-06-29 09:00:00 for doge:usd
# Retrieving data from 2019-06-29 09:00:00 to 2019-06-30 01:40:00 for doge:usd
# Retrieving data from 2019-06-30 01:40:00 to 2019-06-30 18:20:00 for doge:usd
# Retrieving data from 2019-06-30 18:20:00 to 2019-07-01 11:00:00 for doge:usd
# Retrieving data from 2019-07-01 11:00:00 to 2019-07-02 03:40:00 for doge:usd
# Retrieving data from 2019-07-02 03:40:00 to 2019-07-02 20:20:00 for doge:usd
# Retrieving data from 2019-07-02 20:20:00 to 2019-07-03 13:00:00 for doge:usd
# Retrieving data from 2019-07-03 13:00:00 to 2019-07-04 05:40:00 for doge:usd
# Retrieving data from 2019-07-04 05:40:00 to 2019-07-04 22:20:00 for doge:usd
# Retrieving data from 2019-07-04 22:20:00 to 2019-07-05 15:00:00 for doge:usd
# Retrieving data from 2019-07-05 15:00:00 to 2019-07-06 07:40:00 for doge:usd
# Retrieving data from 2019-07-06 07:40:00 to 2019-07-07 00:20:00 for doge:usd
# Retrieving data from 2019-07-07 00:20:00 to 2019-07-07 17:00:00 for doge:usd
# Retrieving data from 2019-07-07 17:00:00 to 2019-07-08 09:40:00 for doge:usd
# Retrieving data from 2019-07-08 09:40:00 to 2019-07-09 02:20:00 for doge:usd
# Retrieving data from 2019-07-09 02:20:00 to 2019-07-09 19:00:00 for doge:usd
# Retrieving data from 2019-07-09 19:00:00 to 2019-07-10 11:40:00 for doge:usd
# Retrieving data from 2019-07-10 11:40:00 to 2019-07-11 04:20:00 for doge:usd
# Retrieving data from 2019-07-11 04:20:00 to 2019-07-11 21:00:00 for doge:usd
# Retrieving data from 2019-07-11 21:00:00 to 2019-07-12 13:40:00 for doge:usd
# Retrieving data from 2019-07-12 13:40:00 to 2019-07-13 06:20:00 for doge:usd
# Retrieving data from 2019-07-13 06:20:00 to 2019-07-13 23:00:00 for doge:usd
# Retrieving data from 2019-07-13 23:00:00 to 2019-07-14 15:40:00 for doge:usd
# Retrieving data from 2019-07-14 15:40:00 to 2019-07-15 08:20:00 for doge:usd
# Retrieving data from 2019-07-15 08:20:00 to 2019-07-16 01:00:00 for doge:usd
# Retrieving data from 2019-07-16 01:00:00 to 2019-07-16 17:40:00 for doge:usd
# Retrieving data from 2019-07-16 17:40:00 to 2019-07-17 10:20:00 for doge:usd
# Retrieving data from 2019-07-17 10:20:00 to 2019-07-18 03:00:00 for doge:usd
# Retrieving data from 2019-07-18 03:00:00 to 2019-07-18 19:40:00 for doge:usd
# Retrieving data from 2019-07-18 19:40:00 to 2019-07-19 12:20:00 for doge:usd
# Retrieving data from 2019-07-19 12:20:00 to 2019-07-20 05:00:00 for doge:usd
# Retrieving data from 2019-07-20 05:00:00 to 2019-07-20 21:40:00 for doge:usd
# Retrieving data from 2019-07-20 21:40:00 to 2019-07-21 14:20:00 for doge:usd
# Retrieving data from 2019-07-21 14:20:00 to 2019-07-22 07:00:00 for doge:usd
# Retrieving data from 2019-07-22 07:00:00 to 2019-07-22 23:40:00 for doge:usd
# Retrieving data from 2019-07-22 23:40:00 to 2019-07-23 16:20:00 for doge:usd
# Retrieving data from 2019-07-23 16:20:00 to 2019-07-24 09:00:00 for doge:usd
# Retrieving data from 2019-07-24 09:00:00 to 2019-07-25 01:40:00 for doge:usd
# Retrieving data from 2019-07-25 01:40:00 to 2019-07-25 18:20:00 for doge:usd
# Retrieving data from 2019-07-25 18:20:00 to 2019-07-26 11:00:00 for doge:usd
# Retrieving data from 2019-07-26 11:00:00 to 2019-07-27 03:40:00 for doge:usd
# Retrieving data from 2019-07-27 03:40:00 to 2019-07-27 20:20:00 for doge:usd
# Retrieving data from 2019-07-27 20:20:00 to 2019-07-28 13:00:00 for doge:usd
# Retrieving data from 2019-07-28 13:00:00 to 2019-07-29 05:40:00 for doge:usd
# Retrieving data from 2019-07-29 05:40:00 to 2019-07-29 22:20:00 for doge:usd
# Retrieving data from 2019-07-29 22:20:00 to 2019-07-30 15:00:00 for doge:usd
# Retrieving data from 2019-07-30 15:00:00 to 2019-07-31 07:40:00 for doge:usd
# Retrieving data from 2019-07-31 07:40:00 to 2019-08-01 00:20:00 for doge:usd
# Retrieving data from 2019-08-01 00:20:00 to 2019-08-01 17:00:00 for doge:usd
# Retrieving data from 2019-08-01 17:00:00 to 2019-08-02 09:40:00 for doge:usd
# Retrieving data from 2019-08-02 09:40:00 to 2019-08-03 02:20:00 for doge:usd
# Retrieving data from 2019-08-03 02:20:00 to 2019-08-03 19:00:00 for doge:usd
# Retrieving data from 2019-08-03 19:00:00 to 2019-08-04 11:40:00 for doge:usd
# Retrieving data from 2019-08-04 11:40:00 to 2019-08-05 04:20:00 for doge:usd
# Retrieving data from 2019-08-05 04:20:00 to 2019-08-05 21:00:00 for doge:usd
# Retrieving data from 2019-08-05 21:00:00 to 2019-08-06 13:40:00 for doge:usd
# Retrieving data from 2019-08-06 13:40:00 to 2019-08-07 06:20:00 for doge:usd
# Retrieving data from 2019-08-07 06:20:00 to 2019-08-07 23:00:00 for doge:usd
# Retrieving data from 2019-08-07 23:00:00 to 2019-08-08 15:40:00 for doge:usd
# Retrieving data from 2019-08-08 15:40:00 to 2019-08-09 08:20:00 for doge:usd
# Retrieving data from 2019-08-09 08:20:00 to 2019-08-10 01:00:00 for doge:usd
# Retrieving data from 2019-08-10 01:00:00 to 2019-08-10 17:40:00 for doge:usd
# Retrieving data from 2019-08-10 17:40:00 to 2019-08-11 10:20:00 for doge:usd
# Retrieving data from 2019-08-11 10:20:00 to 2019-08-12 03:00:00 for doge:usd
# Retrieving data from 2019-08-12 03:00:00 to 2019-08-12 19:40:00 for doge:usd
# Retrieving data from 2019-08-12 19:40:00 to 2019-08-13 12:20:00 for doge:usd
# Retrieving data from 2019-08-13 12:20:00 to 2019-08-14 05:00:00 for doge:usd
# Retrieving data from 2019-08-14 05:00:00 to 2019-08-14 21:40:00 for doge:usd
# Retrieving data from 2019-08-14 21:40:00 to 2019-08-15 14:20:00 for doge:usd
# Retrieving data from 2019-08-15 14:20:00 to 2019-08-16 07:00:00 for doge:usd
# Retrieving data from 2019-08-16 07:00:00 to 2019-08-16 23:40:00 for doge:usd
# Retrieving data from 2019-08-16 23:40:00 to 2019-08-17 16:20:00 for doge:usd
# Retrieving data from 2019-08-17 16:20:00 to 2019-08-18 09:00:00 for doge:usd
# Retrieving data from 2019-08-18 09:00:00 to 2019-08-19 01:40:00 for doge:usd
# Retrieving data from 2019-08-19 01:40:00 to 2019-08-19 18:20:00 for doge:usd
# Retrieving data from 2019-08-19 18:20:00 to 2019-08-20 11:00:00 for doge:usd
# Retrieving data from 2019-08-20 11:00:00 to 2019-08-21 03:40:00 for doge:usd
# Retrieving data from 2019-08-21 03:40:00 to 2019-08-21 20:20:00 for doge:usd
# Retrieving data from 2019-08-21 20:20:00 to 2019-08-22 13:00:00 for doge:usd
# Retrieving data from 2019-08-22 13:00:00 to 2019-08-23 05:40:00 for doge:usd
# Retrieving data from 2019-08-23 05:40:00 to 2019-08-23 22:20:00 for doge:usd
# Retrieving data from 2019-08-23 22:20:00 to 2019-08-24 15:00:00 for doge:usd
# Retrieving data from 2019-08-24 15:00:00 to 2019-08-25 07:40:00 for doge:usd
# Retrieving data from 2019-08-25 07:40:00 to 2019-08-26 00:20:00 for doge:usd
# Retrieving data from 2019-08-26 00:20:00 to 2019-08-26 17:00:00 for doge:usd
# Retrieving data from 2019-08-26 17:00:00 to 2019-08-27 09:40:00 for doge:usd
# Retrieving data from 2019-08-27 09:40:00 to 2019-08-28 02:20:00 for doge:usd
# Retrieving data from 2019-08-28 02:20:00 to 2019-08-28 19:00:00 for doge:usd
# Retrieving data from 2019-08-28 19:00:00 to 2019-08-29 11:40:00 for doge:usd
# Retrieving data from 2019-08-29 11:40:00 to 2019-08-30 04:20:00 for doge:usd
# Retrieving data from 2019-08-30 04:20:00 to 2019-08-30 21:00:00 for doge:usd
# Retrieving data from 2019-08-30 21:00:00 to 2019-08-31 13:40:00 for doge:usd
# Retrieving data from 2019-08-31 13:40:00 to 2019-09-01 06:20:00 for doge:usd
# Retrieving data from 2019-09-01 06:20:00 to 2019-09-01 23:00:00 for doge:usd
# Retrieving data from 2019-09-01 23:00:00 to 2019-09-02 15:40:00 for doge:usd
# Retrieving data from 2019-09-02 15:40:00 to 2019-09-03 08:20:00 for doge:usd
# Retrieving data from 2019-09-03 08:20:00 to 2019-09-04 01:00:00 for doge:usd
# Retrieving data from 2019-09-04 01:00:00 to 2019-09-04 17:40:00 for doge:usd
# Retrieving data from 2019-09-04 17:40:00 to 2019-09-05 10:20:00 for doge:usd
# Retrieving data from 2019-09-05 10:20:00 to 2019-09-06 03:00:00 for doge:usd
# Retrieving data from 2019-09-06 03:00:00 to 2019-09-06 19:40:00 for doge:usd
# Retrieving data from 2019-09-06 19:40:00 to 2019-09-07 12:20:00 for doge:usd
# Retrieving data from 2019-09-07 12:20:00 to 2019-09-08 05:00:00 for doge:usd
# Retrieving data from 2019-09-08 05:00:00 to 2019-09-08 21:40:00 for doge:usd
# Retrieving data from 2019-09-08 21:40:00 to 2019-09-09 14:20:00 for doge:usd
# Retrieving data from 2019-09-09 14:20:00 to 2019-09-10 07:00:00 for doge:usd
# Retrieving data from 2019-09-10 07:00:00 to 2019-09-10 23:40:00 for doge:usd
# Retrieving data from 2019-09-10 23:40:00 to 2019-09-11 16:20:00 for doge:usd
# Retrieving data from 2019-09-11 16:20:00 to 2019-09-12 09:00:00 for doge:usd
# Retrieving data from 2019-09-12 09:00:00 to 2019-09-13 01:40:00 for doge:usd
# Retrieving data from 2019-09-13 01:40:00 to 2019-09-13 18:20:00 for doge:usd
# Retrieving data from 2019-09-13 18:20:00 to 2019-09-14 11:00:00 for doge:usd
# Retrieving data from 2019-09-14 11:00:00 to 2019-09-15 03:40:00 for doge:usd
# Retrieving data from 2019-09-15 03:40:00 to 2019-09-15 20:20:00 for doge:usd
# Retrieving data from 2019-09-15 20:20:00 to 2019-09-16 13:00:00 for doge:usd
# Retrieving data from 2019-09-16 13:00:00 to 2019-09-17 05:40:00 for doge:usd
# Retrieving data from 2019-09-17 05:40:00 to 2019-09-17 22:20:00 for doge:usd
# Retrieving data from 2019-09-17 22:20:00 to 2019-09-18 15:00:00 for doge:usd
# Retrieving data from 2019-09-18 15:00:00 to 2019-09-19 07:40:00 for doge:usd
# Retrieving data from 2019-09-19 07:40:00 to 2019-09-20 00:20:00 for doge:usd
# Retrieving data from 2019-09-20 00:20:00 to 2019-09-20 17:00:00 for doge:usd
# Retrieving data from 2019-09-20 17:00:00 to 2019-09-21 09:40:00 for doge:usd
# Retrieving data from 2019-09-21 09:40:00 to 2019-09-22 02:20:00 for doge:usd
# Retrieving data from 2019-09-22 02:20:00 to 2019-09-22 19:00:00 for doge:usd
# Retrieving data from 2019-09-22 19:00:00 to 2019-09-23 11:40:00 for doge:usd
# Retrieving data from 2019-09-23 11:40:00 to 2019-09-24 04:20:00 for doge:usd
# Retrieving data from 2019-09-24 04:20:00 to 2019-09-24 21:00:00 for doge:usd
# Retrieving data from 2019-09-24 21:00:00 to 2019-09-25 13:40:00 for doge:usd
# Retrieving data from 2019-09-25 13:40:00 to 2019-09-26 06:20:00 for doge:usd
# Retrieving data from 2019-09-26 06:20:00 to 2019-09-26 23:00:00 for doge:usd
# Retrieving data from 2019-09-26 23:00:00 to 2019-09-27 15:40:00 for doge:usd
# Retrieving data from 2019-09-27 15:40:00 to 2019-09-28 08:20:00 for doge:usd
# Retrieving data from 2019-09-28 08:20:00 to 2019-09-29 01:00:00 for doge:usd
# Retrieving data from 2019-09-29 01:00:00 to 2019-09-29 17:40:00 for doge:usd
# Retrieving data from 2019-09-29 17:40:00 to 2019-09-30 10:20:00 for doge:usd
# Retrieving data from 2019-09-30 10:20:00 to 2019-10-01 03:00:00 for doge:usd
# Retrieving data from 2019-10-01 03:00:00 to 2019-10-01 19:40:00 for doge:usd
# Retrieving data from 2019-10-01 19:40:00 to 2019-10-02 12:20:00 for doge:usd
# Retrieving data from 2019-10-02 12:20:00 to 2019-10-03 05:00:00 for doge:usd
# Retrieving data from 2019-10-03 05:00:00 to 2019-10-03 21:40:00 for doge:usd
# Retrieving data from 2019-10-03 21:40:00 to 2019-10-04 14:20:00 for doge:usd
# Retrieving data from 2019-10-04 14:20:00 to 2019-10-05 07:00:00 for doge:usd
# Retrieving data from 2019-10-05 07:00:00 to 2019-10-05 23:40:00 for doge:usd
# Retrieving data from 2019-10-05 23:40:00 to 2019-10-06 16:20:00 for doge:usd
# Retrieving data from 2019-10-06 16:20:00 to 2019-10-07 09:00:00 for doge:usd
# Retrieving data from 2019-10-07 09:00:00 to 2019-10-08 01:40:00 for doge:usd
# Retrieving data from 2019-10-08 01:40:00 to 2019-10-08 18:20:00 for doge:usd
# Retrieving data from 2019-10-08 18:20:00 to 2019-10-09 11:00:00 for doge:usd
# Retrieving data from 2019-10-09 11:00:00 to 2019-10-10 03:40:00 for doge:usd
# Retrieving data from 2019-10-10 03:40:00 to 2019-10-10 20:20:00 for doge:usd
# Retrieving data from 2019-10-10 20:20:00 to 2019-10-11 13:00:00 for doge:usd
# Retrieving data from 2019-10-11 13:00:00 to 2019-10-12 05:40:00 for doge:usd
# Retrieving data from 2019-10-12 05:40:00 to 2019-10-12 22:20:00 for doge:usd
# Retrieving data from 2019-10-12 22:20:00 to 2019-10-13 15:00:00 for doge:usd
# Retrieving data from 2019-10-13 15:00:00 to 2019-10-14 07:40:00 for doge:usd
# Retrieving data from 2019-10-14 07:40:00 to 2019-10-15 00:20:00 for doge:usd
# Retrieving data from 2019-10-15 00:20:00 to 2019-10-15 17:00:00 for doge:usd
# Retrieving data from 2019-10-15 17:00:00 to 2019-10-16 09:40:00 for doge:usd
# Retrieving data from 2019-10-16 09:40:00 to 2019-10-17 02:20:00 for doge:usd
# Retrieving data from 2019-10-17 02:20:00 to 2019-10-17 19:00:00 for doge:usd
# Retrieving data from 2019-10-17 19:00:00 to 2019-10-18 11:40:00 for doge:usd
# Retrieving data from 2019-10-18 11:40:00 to 2019-10-19 04:20:00 for doge:usd
# Retrieving data from 2019-10-19 04:20:00 to 2019-10-19 21:00:00 for doge:usd
# Retrieving data from 2019-10-19 21:00:00 to 2019-10-20 13:40:00 for doge:usd
# Retrieving data from 2019-10-20 13:40:00 to 2019-10-21 06:20:00 for doge:usd
# Retrieving data from 2019-10-21 06:20:00 to 2019-10-21 23:00:00 for doge:usd
# Retrieving data from 2019-10-21 23:00:00 to 2019-10-22 15:40:00 for doge:usd
# Retrieving data from 2019-10-22 15:40:00 to 2019-10-23 08:20:00 for doge:usd
# Retrieving data from 2019-10-23 08:20:00 to 2019-10-24 01:00:00 for doge:usd
# Retrieving data from 2019-10-24 01:00:00 to 2019-10-24 17:40:00 for doge:usd
# Retrieving data from 2019-10-24 17:40:00 to 2019-10-25 10:20:00 for doge:usd
# Retrieving data from 2019-10-25 10:20:00 to 2019-10-26 03:00:00 for doge:usd
# Retrieving data from 2019-10-26 03:00:00 to 2019-10-26 19:40:00 for doge:usd
# Retrieving data from 2019-10-26 19:40:00 to 2019-10-27 12:20:00 for doge:usd
# Retrieving data from 2019-10-27 12:20:00 to 2019-10-28 05:00:00 for doge:usd
# Retrieving data from 2019-10-28 05:00:00 to 2019-10-28 21:40:00 for doge:usd
# Retrieving data from 2019-10-28 21:40:00 to 2019-10-29 14:20:00 for doge:usd
# Retrieving data from 2019-10-29 14:20:00 to 2019-10-30 07:00:00 for doge:usd
# Retrieving data from 2019-10-30 07:00:00 to 2019-10-30 23:40:00 for doge:usd
# Retrieving data from 2019-10-30 23:40:00 to 2019-10-31 16:20:00 for doge:usd
# Retrieving data from 2019-10-31 16:20:00 to 2019-11-01 09:00:00 for doge:usd
# Retrieving data from 2019-11-01 09:00:00 to 2019-11-02 01:40:00 for doge:usd
# Retrieving data from 2019-11-02 01:40:00 to 2019-11-02 18:20:00 for doge:usd
# Retrieving data from 2019-11-02 18:20:00 to 2019-11-03 11:00:00 for doge:usd
# Retrieving data from 2019-11-03 11:00:00 to 2019-11-04 03:40:00 for doge:usd
# Retrieving data from 2019-11-04 03:40:00 to 2019-11-04 20:20:00 for doge:usd
# Retrieving data from 2019-11-04 20:20:00 to 2019-11-05 13:00:00 for doge:usd
# Retrieving data from 2019-11-05 13:00:00 to 2019-11-06 05:40:00 for doge:usd
# Retrieving data from 2019-11-06 05:40:00 to 2019-11-06 22:20:00 for doge:usd
# Retrieving data from 2019-11-06 22:20:00 to 2019-11-07 15:00:00 for doge:usd
# Retrieving data from 2019-11-07 15:00:00 to 2019-11-08 07:40:00 for doge:usd
# Retrieving data from 2019-11-08 07:40:00 to 2019-11-09 00:20:00 for doge:usd
# Retrieving data from 2019-11-09 00:20:00 to 2019-11-09 17:00:00 for doge:usd
# Retrieving data from 2019-11-09 17:00:00 to 2019-11-10 09:40:00 for doge:usd
# Retrieving data from 2019-11-10 09:40:00 to 2019-11-11 02:20:00 for doge:usd
# Retrieving data from 2019-11-11 02:20:00 to 2019-11-11 19:00:00 for doge:usd
# Retrieving data from 2019-11-11 19:00:00 to 2019-11-12 11:40:00 for doge:usd
# Retrieving data from 2019-11-12 11:40:00 to 2019-11-13 04:20:00 for doge:usd
# Retrieving data from 2019-11-13 04:20:00 to 2019-11-13 21:00:00 for doge:usd
# Retrieving data from 2019-11-13 21:00:00 to 2019-11-14 13:40:00 for doge:usd
# Retrieving data from 2019-11-14 13:40:00 to 2019-11-15 06:20:00 for doge:usd
# Retrieving data from 2019-11-15 06:20:00 to 2019-11-15 23:00:00 for doge:usd
# Retrieving data from 2019-11-15 23:00:00 to 2019-11-16 15:40:00 for doge:usd
# Retrieving data from 2019-11-16 15:40:00 to 2019-11-17 08:20:00 for doge:usd
# Retrieving data from 2019-11-17 08:20:00 to 2019-11-18 01:00:00 for doge:usd
# Retrieving data from 2019-11-18 01:00:00 to 2019-11-18 17:40:00 for doge:usd
# Retrieving data from 2019-11-18 17:40:00 to 2019-11-19 10:20:00 for doge:usd
# Retrieving data from 2019-11-19 10:20:00 to 2019-11-20 03:00:00 for doge:usd
# Retrieving data from 2019-11-20 03:00:00 to 2019-11-20 19:40:00 for doge:usd
# Retrieving data from 2019-11-20 19:40:00 to 2019-11-21 12:20:00 for doge:usd
# Retrieving data from 2019-11-21 12:20:00 to 2019-11-22 05:00:00 for doge:usd
# Retrieving data from 2019-11-22 05:00:00 to 2019-11-22 21:40:00 for doge:usd
# Retrieving data from 2019-11-22 21:40:00 to 2019-11-23 14:20:00 for doge:usd
# Retrieving data from 2019-11-23 14:20:00 to 2019-11-24 07:00:00 for doge:usd
# Retrieving data from 2019-11-24 07:00:00 to 2019-11-24 23:40:00 for doge:usd
# Retrieving data from 2019-11-24 23:40:00 to 2019-11-25 16:20:00 for doge:usd
# Retrieving data from 2019-11-25 16:20:00 to 2019-11-26 09:00:00 for doge:usd
# Retrieving data from 2019-11-26 09:00:00 to 2019-11-27 01:40:00 for doge:usd
# Retrieving data from 2019-11-27 01:40:00 to 2019-11-27 18:20:00 for doge:usd
# Retrieving data from 2019-11-27 18:20:00 to 2019-11-28 11:00:00 for doge:usd
# Retrieving data from 2019-11-28 11:00:00 to 2019-11-29 03:40:00 for doge:usd
# Retrieving data from 2019-11-29 03:40:00 to 2019-11-29 20:20:00 for doge:usd
# Retrieving data from 2019-11-29 20:20:00 to 2019-11-30 13:00:00 for doge:usd
# Retrieving data from 2019-11-30 13:00:00 to 2019-12-01 05:40:00 for doge:usd
# Retrieving data from 2019-12-01 05:40:00 to 2019-12-01 22:20:00 for doge:usd
# Retrieving data from 2019-12-01 22:20:00 to 2019-12-02 15:00:00 for doge:usd
# Retrieving data from 2019-12-02 15:00:00 to 2019-12-03 07:40:00 for doge:usd
# Retrieving data from 2019-12-03 07:40:00 to 2019-12-04 00:20:00 for doge:usd
# Retrieving data from 2019-12-04 00:20:00 to 2019-12-04 17:00:00 for doge:usd
# Retrieving data from 2019-12-04 17:00:00 to 2019-12-05 09:40:00 for doge:usd
# Retrieving data from 2019-12-05 09:40:00 to 2019-12-06 02:20:00 for doge:usd
# Retrieving data from 2019-12-06 02:20:00 to 2019-12-06 19:00:00 for doge:usd
# Retrieving data from 2019-12-06 19:00:00 to 2019-12-07 11:40:00 for doge:usd
# Retrieving data from 2019-12-07 11:40:00 to 2019-12-08 04:20:00 for doge:usd
# Retrieving data from 2019-12-08 04:20:00 to 2019-12-08 21:00:00 for doge:usd
# Retrieving data from 2019-12-08 21:00:00 to 2019-12-09 13:40:00 for doge:usd
# Retrieving data from 2019-12-09 13:40:00 to 2019-12-10 06:20:00 for doge:usd
# Retrieving data from 2019-12-10 06:20:00 to 2019-12-10 23:00:00 for doge:usd
# Retrieving data from 2019-12-10 23:00:00 to 2019-12-11 15:40:00 for doge:usd
# Retrieving data from 2019-12-11 15:40:00 to 2019-12-12 08:20:00 for doge:usd
# Retrieving data from 2019-12-12 08:20:00 to 2019-12-13 01:00:00 for doge:usd
# Retrieving data from 2019-12-13 01:00:00 to 2019-12-13 17:40:00 for doge:usd
# Retrieving data from 2019-12-13 17:40:00 to 2019-12-14 10:20:00 for doge:usd
# Retrieving data from 2019-12-14 10:20:00 to 2019-12-15 03:00:00 for doge:usd
# Retrieving data from 2019-12-15 03:00:00 to 2019-12-15 19:40:00 for doge:usd
# Retrieving data from 2019-12-15 19:40:00 to 2019-12-16 12:20:00 for doge:usd
# Retrieving data from 2019-12-16 12:20:00 to 2019-12-17 05:00:00 for doge:usd
# Retrieving data from 2019-12-17 05:00:00 to 2019-12-17 21:40:00 for doge:usd
# Retrieving data from 2019-12-17 21:40:00 to 2019-12-18 14:20:00 for doge:usd
# Retrieving data from 2019-12-18 14:20:00 to 2019-12-19 07:00:00 for doge:usd
# Retrieving data from 2019-12-19 07:00:00 to 2019-12-19 23:40:00 for doge:usd
# Retrieving data from 2019-12-19 23:40:00 to 2019-12-20 16:20:00 for doge:usd
# Retrieving data from 2019-12-20 16:20:00 to 2019-12-21 09:00:00 for doge:usd
# Retrieving data from 2019-12-21 09:00:00 to 2019-12-22 01:40:00 for doge:usd
# Retrieving data from 2019-12-22 01:40:00 to 2019-12-22 18:20:00 for doge:usd
# Retrieving data from 2019-12-22 18:20:00 to 2019-12-23 11:00:00 for doge:usd
# Retrieving data from 2019-12-23 11:00:00 to 2019-12-24 03:40:00 for doge:usd
# Retrieving data from 2019-12-24 03:40:00 to 2019-12-24 20:20:00 for doge:usd
# Retrieving data from 2019-12-24 20:20:00 to 2019-12-25 13:00:00 for doge:usd
# Retrieving data from 2019-12-25 13:00:00 to 2019-12-26 05:40:00 for doge:usd
# Retrieving data from 2019-12-26 05:40:00 to 2019-12-26 22:20:00 for doge:usd
# Retrieving data from 2019-12-26 22:20:00 to 2019-12-27 15:00:00 for doge:usd
# Retrieving data from 2019-12-27 15:00:00 to 2019-12-28 07:40:00 for doge:usd
# Retrieving data from 2019-12-28 07:40:00 to 2019-12-29 00:20:00 for doge:usd
# Retrieving data from 2019-12-29 00:20:00 to 2019-12-29 17:00:00 for doge:usd
# Retrieving data from 2019-12-29 17:00:00 to 2019-12-30 09:40:00 for doge:usd
# Retrieving data from 2019-12-30 09:40:00 to 2019-12-31 02:20:00 for doge:usd
# Retrieving data from 2019-12-31 02:20:00 to 2019-12-31 19:00:00 for doge:usd
# Retrieving data from 2019-12-31 19:00:00 to 2020-01-01 11:40:00 for doge:usd
# Retrieving data from 2020-01-01 11:40:00 to 2020-01-02 04:20:00 for doge:usd
# Done downloading data. Saving data to .csv.
# Done saving data. Moving to next currency.
# Data retrieval done
